# %% [markdown]
# ## Exercise 3 Plots
# 1. **Proof Generation Times**
# 2. **Proof Validation Times**
# 3. **Proof Sizes**

# %% [markdown]
# ## Proof Generation Times Comparison

# %%
import matplotlib.pyplot as plt

legoGroth16ProofTimes = [ 10.563, 0.027, 5.954, 11.906, 17.98 ] 
bulletProofProofTimes = [ 0.113, 0.028, 0.36, 0.692, 1.051 ] 

# Create the bar chart
plt.bar(
    [i - 0.1 for i in range(len(legoGroth16ProofTimes))],
    legoGroth16ProofTimes,
    width=0.2,
    label="LegoGroth16",
    color="blue",
)
plt.bar(
    [i + 0.1 for i in range(len(bulletProofProofTimes))],
    bulletProofProofTimes,
    width=0.2,
    label="BulletProof++",
    color="red",
)

# Add labels and title
plt.xlabel("Number of range proofs")
plt.ylabel("Proof Generation Time (seconds)")
plt.title("Comparison of Proof Generation Times")
plt.xticks(range(len(legoGroth16ProofTimes)), ["Setup", "0", "1", "2", "3"])
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Proof Validation Times

# %%
import matplotlib.pyplot as plt


legoGroth16VerificationTimes = [ 0.031, 0.133, 0.235, 0.342 ]
bulletProofVerificationTimes = [ 0.03, 0.048, 0.06, 0.073 ]

# Create the bar chart
plt.bar(
    [i - 0.1 for i in range(len(legoGroth16VerificationTimes))],
    legoGroth16VerificationTimes,
    width=0.2,
    label="LegoGroth16",
    color="blue",
)
plt.bar(
    [i + 0.1 for i in range(len(bulletProofVerificationTimes))],
    bulletProofVerificationTimes,
    width=0.2,
    label="BulletProof++",
    color="red",
)

# Add labels and title
plt.xlabel("Number of range proofs")
plt.ylabel("Proof Generation Time (seconds)")
plt.title("Comparison of Proof Generation Times")
plt.xticks(range(len(legoGroth16VerificationTimes)), ["0", "1", "2", "3"])
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Proof Sizes

# %%
import matplotlib.pyplot as plt

legoGroth16Size = [0.491, 0.892, 1.293, 1.694]
bulletProofSize = [0.491, 1.798, 3.105, 4.412]

# Create the bar chart
plt.bar(
    [i - 0.1 for i in range(len(legoGroth16Size))],
    legoGroth16Size,
    width=0.2,
    label="LegoGroth16",
    color="blue",
)
plt.bar(
    [i + 0.1 for i in range(len(bulletProofSize))],
    bulletProofSize,
    width=0.2,
    label="BulletProof++",
    color="red",
)

# Add labels and title
plt.xlabel("Number of range proofs")
plt.ylabel("Size of proof in K.bytes")
plt.title("Comparison of Proof Sizes")
plt.xticks(range(len(legoGroth16Size)), ["None", "1", "2", "3"])
plt.legend()

# Show the plot
plt.show()
